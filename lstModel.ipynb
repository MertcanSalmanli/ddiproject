# %%
#--LSTM MODEL EĞİTİMİ--


import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical

# Vektörleştirilmiş verilere sahip CSV dosyasını yükleme
vector_df = pd.read_csv('vektorlenen_dosya.csv')

# Etiketler ve vektörleri birleştirme
etiketler = vector_df['Etiket']
X = vector_df.drop('Etiket', axis=1).values

# Etiketleri sayısal değerlere dönüştürme
label_encoder = LabelEncoder()
etiketler = label_encoder.fit_transform(etiketler)

# İkili sınıflandırma mı çok sınıflı sınıflandırma mı olduğunu kontrol etme (değişti)
num_classes = len(np.unique(etiketler))
etiketler = to_categorical(etiketler)
loss_function = 'categorical_crossentropy'
activation_function = 'softmax'
output_units = num_classes


# Verileri uygun forma dönüştürme
X = X.astype(float)  
X = X.reshape((X.shape[0], X.shape[1], 1))

# eğitim ve test setleri
X_train, X_test, y_train, y_test = train_test_split(X, etiketler, test_size=0.2, random_state=42)

# LSTM modeli
model = Sequential()
model.add(LSTM(100, input_shape=(X_train.shape[1], 1)))
model.add(Dense(output_units, activation=activation_function))

# Modeli uygula
model.compile(optimizer='adam', loss=loss_function, metrics=['accuracy'])

# Modeli eğitme
model.fit(X_train, y_train, epochs=30, batch_size=32, validation_split=0.2)

# Modeli değerlendirme
loss, accuracy = model.evaluate(X_test, y_test)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
# Out:
# Epoch 1/30
# c:\Users\Mertcan\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.3116 - loss: 1.9522 - val_accuracy: 0.3531 - val_loss: 1.8525
# Epoch 2/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.3324 - loss: 1.8711 - val_accuracy: 0.3531 - val_loss: 1.8239
# Epoch 3/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - accuracy: 0.3480 - loss: 1.8127 - val_accuracy: 0.4913 - val_loss: 1.5376
# Epoch 4/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - accuracy: 0.5143 - loss: 1.4247 - val_accuracy: 0.5850 - val_loss: 1.2541
# Epoch 5/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.5674 - loss: 1.2362 - val_accuracy: 0.6581 - val_loss: 1.1409
# Epoch 6/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.6447 - loss: 1.1195 - val_accuracy: 0.7144 - val_loss: 0.9995
# Epoch 7/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - accuracy: 0.7150 - loss: 0.9251 - val_accuracy: 0.7387 - val_loss: 0.8363
# Epoch 8/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7188 - loss: 0.8562 - val_accuracy: 0.7319 - val_loss: 0.8368
# Epoch 9/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.7345 - loss: 0.8195 - val_accuracy: 0.7538 - val_loss: 0.7845
# Epoch 10/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7600 - loss: 0.7588 - val_accuracy: 0.7556 - val_loss: 0.7729
# Epoch 11/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7482 - loss: 0.7715 - val_accuracy: 0.7681 - val_loss: 0.7443
# Epoch 12/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7715 - loss: 0.7174 - val_accuracy: 0.7563 - val_loss: 0.7691
# Epoch 13/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7760 - loss: 0.6918 - val_accuracy: 0.7738 - val_loss: 0.7269
# Epoch 14/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7698 - loss: 0.7031 - val_accuracy: 0.7794 - val_loss: 0.6967
# Epoch 15/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7785 - loss: 0.6927 - val_accuracy: 0.7519 - val_loss: 0.7576
# Epoch 16/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7740 - loss: 0.7014 - val_accuracy: 0.7788 - val_loss: 0.6982
# Epoch 17/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7873 - loss: 0.6680 - val_accuracy: 0.7638 - val_loss: 0.7035
# Epoch 18/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7926 - loss: 0.6574 - val_accuracy: 0.7756 - val_loss: 0.6904
# Epoch 19/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7902 - loss: 0.6556 - val_accuracy: 0.7862 - val_loss: 0.6949
# Epoch 20/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.7798 - loss: 0.6852 - val_accuracy: 0.7819 - val_loss: 0.6803
# Epoch 21/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - accuracy: 0.7856 - loss: 0.6531 - val_accuracy: 0.7881 - val_loss: 0.6728
# Epoch 22/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7792 - loss: 0.6683 - val_accuracy: 0.7825 - val_loss: 0.6635
# Epoch 23/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.8012 - loss: 0.6213 - val_accuracy: 0.7875 - val_loss: 0.6601
# Epoch 24/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7860 - loss: 0.6660 - val_accuracy: 0.7775 - val_loss: 0.6933
# Epoch 25/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.7871 - loss: 0.6540 - val_accuracy: 0.7956 - val_loss: 0.6671
# Epoch 26/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.7900 - loss: 0.6527 - val_accuracy: 0.7981 - val_loss: 0.6584
# Epoch 27/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7911 - loss: 0.6522 - val_accuracy: 0.7625 - val_loss: 0.7058
# Epoch 28/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7905 - loss: 0.6544 - val_accuracy: 0.7862 - val_loss: 0.6482
# Epoch 29/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.7974 - loss: 0.6317 - val_accuracy: 0.7906 - val_loss: 0.6519
# Epoch 30/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.7914 - loss: 0.6383 - val_accuracy: 0.7887 - val_loss: 0.6563
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7973 - loss: 0.6555
# Test Loss: 0.6515405774116516
# Test Accuracy: 0.7944999933242798
